# %%
# Magic command to show plots in same cell as code
# %matplotlib inline

# %%
# Import dependencies
import matplotlib.pyplot as plt

# %%
x = [50,42,39,34,32,48,22,17,8,13]
y = [17,19,21,22,24,23,34,31,43,35]

# %%
plt.scatter(x,y, c='mediumturquoise',marker='x',s=x)
plt.xlabel('Total Number of Rides (Per City)')
plt.ylabel('Average Fare ($)')
plt.title('Average Fare vs. Total Rides')
# Out:
# Text(0.5, 1.0, 'Average Fare vs. Total Rides')

# %%
# Matlab Method

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# The 'o' makes the plot a scatter
plt.plot(x_axis, y_axis, 'o')

# %%
# Skill Drill

# Change the color of markers to red.
plt.plot(y_axis,x_axis, 'o', color='red')
# Add a legend for Chicago
plt.legend(["Chigago"])
# Add a title and axes labels
plt.title("PyBer Fare by Month")
plt.xlabel("Fare ($)")
plt.ylabel("Date")
# Add a limit for x-axis data 0-50
plt.xlim(0,50)
# Invert the y-axis so that Jan is on top
plt.gca().invert_yaxis()

# %%
# Create a bubble chart
plt.scatter(x_axis, y_axis)
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
# Make the dots bigger
y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)

plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-fb4805a9eb61> in <module>
# ----> 1 new_list = [expression for item in list if conditional]
#       2 plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])
#
# TypeError: 'type' object is not iterable
